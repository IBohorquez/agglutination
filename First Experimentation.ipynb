# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, RMSprop
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
from skimage.color import rgb2gray
from skimage.transform import resize
import random
from tqdm import tqdm

from tensorflow.keras import backend as K
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Reading pre-processed dataset

# %%
####################################
## Reading the pre-processed dataset

path_X = '/content/drive/MyDrive/Agglutination/Dataset/Pre-Processed Dataset/' + 'Xcrop_rgb_v2.pickle'
path_y = '/content/drive/MyDrive/Agglutination/Dataset/Pre-Processed Dataset/' + 'ycrop_rgb_v2.pickle'

pickle_in = open(path_X, "rb")
X = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(path_y, "rb")
y = pickle.load(pickle_in)
pickle_in.close()

print(X.shape, y.shape)
# Out:
# (1285, 224, 224, 3) (1285,)

# %% [markdown]
# #For saving the calculated metrics

# %%
accuracies = []
precisions = []
sensitivities = []
specificities = []
F1_scores = []
auc_values = []

# %% [markdown]
# #Training and Testing the model for 50 iterations

# %%
for j in range(50):

    print('--------------')
    print('ITERATION:', j+1)
    print('--------------')

    X_train_, X_test, y_train_, y_test = train_test_split(X, y, test_size = 0.2, shuffle=True)
    X_train, X_val, y_train, y_val = train_test_split(X_train_, y_train_, test_size = 0.2, shuffle=True)

    print()
    print('---------------------------------------------------------------------------')
    print('There are', X_train.shape[0], 'images for the Training with their respectives', y_train.shape[0], 'labels.')
    print('There are', X_val.shape[0], 'images for the Validation with their respectives', y_val.shape[0], 'labels.')
    print('There are', X_test.shape[0], 'images for the Testing with their respectives', y_test.shape[0], 'labels.')
    print('---------------------------------------------------------------------------')
    print()

    print('-----------------------------------------------------------------------------------------------------------')
    sum_neg = 0
    sum_pos = 0

    for i in range(len(y_train)):
        if y_train[i]==0:
            sum_neg += 1
        else:
            sum_pos +=1 

    print('There are', sum_neg, 'negatives images and', sum_pos, 'positives images on the Training dataset: rate=', sum_neg/sum_pos)

    sum_neg = 0
    sum_pos = 0

    for i in range(len(y_val)):
        if y_train[i]==0:
            sum_neg += 1
        else:
            sum_pos +=1 

    print('There are', sum_neg, 'negatives images and', sum_pos, 'positives images on the Validation dataset: rate=', sum_neg/sum_pos)

    sum_neg = 0
    sum_pos = 0

    for i in range(len(y_test)):
        if y_test[i]==0:
            sum_neg += 1
        else:
            sum_pos +=1 

    print('There are', sum_neg, 'negatives images and', sum_pos, 'positives images on the Testing dataset: rate=', sum_neg/sum_pos)
    print('-----------------------------------------------------------------------------------------------------------')
    print()

    ########################################
    ## Defining the Transfer Learning model

    conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    conv_base.trainable = False

    model = None
    model = Sequential()
    model.add(conv_base)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0005), metrics=['accuracy'])

    print(model.summary())
    print()
    print('------------------------------------')
    print('Training the Tranfer Learning Model')
    print('------------------------------------')
    print()

    ######################
    ## Training the model

    history = model.fit(X_train, y_train, batch_size=32, epochs=30, shuffle=False, verbose=1, validation_data=(X_val, y_val))

    print()
    print('------------------------')
    print('Evaluation of the Model')
    print('------------------------')

    ############################################
    ## Testing the model on the Testing dataset

    test_loss, test_accuracy = model.evaluate(X_test, y_test)
    print()
    print('Accuracy on the Testing dataset:', test_accuracy*100, '%')
    print()

    #######################
    ## Calculating metrics

    y_preds = model.predict(X_test).ravel()
    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    auc_value = auc(fpr, tpr)

    mythreshold = 0.5
    y_pred = (model.predict(X_test)>= mythreshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    acc = (tn + tp)/(tn + fp + fn + tp)
    prec = tp/(tp + fp)
    sens = tp/(tp + fn)
    spec = tn/(tn + fp)
    f1_score = (2*prec*sens)/(prec + sens)

    accuracies.append(acc)
    precisions.append(prec)
    sensitivities.append(sens)
    specificities.append(spec)
    F1_scores.append(f1_score)
    auc_values.append(auc_value)

    #############################################
    ## Saving the models with certain conditions

    if test_accuracy > 0.96 and auc_value > 0.99:
        model.save('/content/drive/MyDrive/Agglutination/Best models/' + 'modelo_acc_{:4f}_iter_{}.h5'.format(test_accuracy,j+1))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Epoch 26/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0541 - accuracy: 0.9866 - val_loss: 0.0969 - val_accuracy: 0.9660
# Epoch 27/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0518 - accuracy: 0.9866 - val_loss: 0.0948 - val_accuracy: 0.9660
# Epoch 28/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0497 - accuracy: 0.9878 - val_loss: 0.0930 - val_accuracy: 0.9660
# Epoch 29/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0478 - accuracy: 0.9878 - val_loss: 0.0914 - val_accuracy: 0.9660
# Epoch 30/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0460 - accuracy: 0.9878 - val_loss: 0.0902 - val_accuracy: 0.9660
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 216ms/step - loss: 0.0986 - accuracy: 0.9572
#
# Accuracy on the Testing dataset: 95.7198441028595 %
#
# --------------
# ITERATION: 4
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 400 negatives images and 422 positives images on the Training dataset: rate= 0.9478672985781991
# There are 93 negatives images and 113 positives images on the Validation dataset: rate= 0.8230088495575221
# There are 129 negatives images and 128 positives images on the Testing dataset: rate= 1.0078125
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 326ms/step - loss: 0.4257 - accuracy: 0.8260 - val_loss: 0.3113 - val_accuracy: 0.9078
# Epoch 2/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1758 - accuracy: 0.9294 - val_loss: 0.2088 - val_accuracy: 0.9223
# Epoch 3/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1527 - accuracy: 0.9392 - val_loss: 0.1918 - val_accuracy: 0.9223
# Epoch 4/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 407 negatives images and 415 positives images on the Training dataset: rate= 0.980722891566265
# There are 102 negatives images and 104 positives images on the Validation dataset: rate= 0.9807692307692307
# There are 121 negatives images and 136 positives images on the Testing dataset: rate= 0.8897058823529411
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 320ms/step - loss: 0.5167 - accuracy: 0.8127 - val_loss: 0.1858 - val_accuracy: 0.9078
# Epoch 2/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.2038 - accuracy: 0.9173 - val_loss: 0.1504 - val_accuracy: 0.9272
# Epoch 3/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1654 - accuracy: 0.9355 - val_loss: 0.1386 - val_accuracy: 0.9272
# Epoch 4/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.1560 - accuracy: 0.9355 - val_loss: 0.1384 - val_accuracy: 0.9272
# Epoch 5/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1434 - accuracy: 0.9428 - val_loss: 0.1332 - val_accuracy: 0.9272
# Epoch 6/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1314 - accuracy: 0.9453 - val_loss: 0.1257 - val_accuracy: 0.9320
# Epoch 7/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1219 - accuracy: 0.9489 - val_loss: 0.1189 - val_accuracy: 0.9369
# Epoch 8/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1140 - accuracy: 0.9538 - val_loss: 0.1132 - val_accuracy: 0.9417
# Epoch 9/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1073 - accuracy: 0.9550 - val_loss: 0.1060 - val_accuracy: 0.9417
# Epoch 10/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1004 - accuracy: 0.9623 - val_loss: 0.1027 - val_accuracy: 0.9417
# Epoch 11/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0946 - accuracy: 0.9684 - val_loss: 0.0992 - val_accuracy: 0.9515
# Epoch 12/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0894 - accuracy: 0.9720 - val_loss: 0.0947 - val_accuracy: 0.9563
# Epoch 13/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0834 - accuracy: 0.9720 - val_loss: 0.0920 - val_accuracy: 0.9563
# Epoch 14/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0785 - accuracy: 0.9732 - val_loss: 0.0894 - val_accuracy: 0.9563
# Epoch 15/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0729 - accuracy: 0.9732 - val_loss: 0.0865 - val_accuracy: 0.9563
# Epoch 16/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0692 - accuracy: 0.9757 - val_loss: 0.0852 - val_accuracy: 0.9563
# Epoch 17/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0643 - accuracy: 0.9769 - val_loss: 0.0836 - val_accuracy: 0.9563
# Epoch 18/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0600 - accuracy: 0.9793 - val_loss: 0.0811 - val_accuracy: 0.9612
# Epoch 19/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0565 - accuracy: 0.9854 - val_loss: 0.0790 - val_accuracy: 0.9612
# Epoch 20/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0529 - accuracy: 0.9866 - val_loss: 0.0795 - val_accuracy: 0.9612
# Epoch 21/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0494 - accuracy: 0.9866 - val_loss: 0.0778 - val_accuracy: 0.9612
# Epoch 22/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0460 - accuracy: 0.9866 - val_loss: 0.0784 - val_accuracy: 0.9612
# Epoch 23/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0416 - accuracy: 0.9891 - val_loss: 0.0762 - val_accuracy: 0.9612
# Epoch 24/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0389 - accuracy: 0.9903 - val_loss: 0.0765 - val_accuracy: 0.9612
# Epoch 25/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0365 - accuracy: 0.9915 - val_loss: 0.0776 - val_accuracy: 0.9612
# Epoch 26/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0335 - accuracy: 0.9927 - val_loss: 0.0785 - val_accuracy: 0.9563
# Epoch 27/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0308 - accuracy: 0.9939 - val_loss: 0.0780 - val_accuracy: 0.9563
# Epoch 28/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0289 - accuracy: 0.9939 - val_loss: 0.0800 - val_accuracy: 0.9515
# Epoch 29/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0276 - accuracy: 0.9939 - val_loss: 0.0807 - val_accuracy: 0.9563
# Epoch 30/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0264 - accuracy: 0.9939 - val_loss: 0.0830 - val_accuracy: 0.9612
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 220ms/step - loss: 0.0955 - accuracy: 0.9572
#
# Accuracy on the Testing dataset: 95.7198441028595 %
#
# --------------
# ITERATION: 6
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 390 negatives images and 432 positives images on the Training dataset: rate= 0.9027777777777778
# There are 108 negatives images and 98 positives images on the Validation dataset: rate= 1.1020408163265305
# There are 137 negatives images and 120 positives images on the Testing dataset: rate= 1.1416666666666666
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 10s 347ms/step - loss: 0.5820 - accuracy: 0.7810 - val_loss: 0.1705 - val_accuracy: 0.9369
# Epoch 2/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1994 - accuracy: 0.9221 - val_loss: 0.1487 - val_accuracy: 0.9223
# Epoch 3/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1762 - accuracy: 0.9258 - val_loss: 0.1279 - val_accuracy: 0.9515
# Epoch 4/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1654 - accuracy: 0.9319 - val_loss: 0.1175 - val_accuracy: 0.9612
# Epoch 5/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1589 - accuracy: 0.9331 - val_loss: 0.1110 - val_accuracy: 0.9660
# Epoch 6/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1524 - accuracy: 0.9355 - val_loss: 0.1059 - val_accuracy: 0.9709
# Epoch 7/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1460 - accuracy: 0.9331 - val_loss: 0.1016 - val_accuracy: 0.9709
# Epoch 8/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1400 - accuracy: 0.9355 - val_loss: 0.0975 - val_accuracy: 0.9757
# Epoch 9/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1346 - accuracy: 0.9392 - val_loss: 0.0939 - val_accuracy: 0.9757
# Epoch 10/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1301 - accuracy: 0.9404 - val_loss: 0.0905 - val_accuracy: 0.9757
# Epoch 11/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1256 - accuracy: 0.9440 - val_loss: 0.0872 - val_accuracy: 0.9757
# Epoch 12/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1216 - accuracy: 0.9453 - val_loss: 0.0845 - val_accuracy: 0.9757
# Epoch 13/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1180 - accuracy: 0.9477 - val_loss: 0.0813 - val_accuracy: 0.9757
# Epoch 14/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1144 - accuracy: 0.9513 - val_loss: 0.0789 - val_accuracy: 0.9709
# Epoch 15/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1101 - accuracy: 0.9526 - val_loss: 0.0766 - val_accuracy: 0.9709
# Epoch 16/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1056 - accuracy: 0.9538 - val_loss: 0.0754 - val_accuracy: 0.9709
# Epoch 17/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1007 - accuracy: 0.9586 - val_loss: 0.0742 - val_accuracy: 0.9709
# Epoch 18/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0959 - accuracy: 0.9611 - val_loss: 0.0731 - val_accuracy: 0.9806
# Epoch 19/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0913 - accuracy: 0.9623 - val_loss: 0.0725 - val_accuracy: 0.9806
# Epoch 20/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0865 - accuracy: 0.9659 - val_loss: 0.0728 - val_accuracy: 0.9806
# Epoch 21/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0831 - accuracy: 0.9672 - val_loss: 0.0722 - val_accuracy: 0.9757
# Epoch 22/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0797 - accuracy: 0.9684 - val_loss: 0.0723 - val_accuracy: 0.9709
# Epoch 23/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0767 - accuracy: 0.9684 - val_loss: 0.0723 - val_accuracy: 0.9709
# Epoch 24/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0738 - accuracy: 0.9720 - val_loss: 0.0731 - val_accuracy: 0.9709
# Epoch 25/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0712 - accuracy: 0.9745 - val_loss: 0.0733 - val_accuracy: 0.9806
# Epoch 26/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0689 - accuracy: 0.9745 - val_loss: 0.0739 - val_accuracy: 0.9757
# Epoch 27/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0666 - accuracy: 0.9769 - val_loss: 0.0746 - val_accuracy: 0.9757
# Epoch 28/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0646 - accuracy: 0.9781 - val_loss: 0.0764 - val_accuracy: 0.9660
# Epoch 29/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0626 - accuracy: 0.9805 - val_loss: 0.0786 - val_accuracy: 0.9660
# Epoch 30/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0613 - accuracy: 0.9793 - val_loss: 0.0803 - val_accuracy: 0.9660
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 218ms/step - loss: 0.1288 - accuracy: 0.9416
#
# Accuracy on the Testing dataset: 94.16342377662659 %
#
# --------------
# ITERATION: 7
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 401 negatives images and 421 positives images on the Training dataset: rate= 0.9524940617577197
# There are 104 negatives images and 102 positives images on the Validation dataset: rate= 1.0196078431372548
# There are 123 negatives images and 134 positives images on the Testing dataset: rate= 0.917910447761194
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (
30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0618 - accuracy: 0.9805 - val_loss: 0.1428 - val_accuracy: 0.9466
# Epoch 25/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0588 - accuracy: 0.9818 - val_loss: 0.1412 - val_accuracy: 0.9466
# Epoch 26/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0552 - accuracy: 0.9830 - val_loss: 0.1384 - val_accuracy: 0.9466
# Epoch 27/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0523 - accuracy: 0.9842 - val_loss: 0.1375 - val_accuracy: 0.9466
# Epoch 28/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0497 - accuracy: 0.9842 - val_loss: 0.1362 - val_accuracy: 0.9466
# Epoch 29/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0470 - accuracy: 0.9866 - val_loss: 0.1348 - val_accuracy: 0.9466
# Epoch 30/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0442 - accuracy: 0.9903 - val_loss: 0.1325 - val_accuracy: 0.9466
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 220ms/step - loss: 0.0608 - accuracy: 0.9805
#
# Accuracy on the Testing dataset: 98.05447459220886 %
#
# --------------
# ITERATION: 8
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 406 negatives images and 416 positives images on the Training dataset: rate= 0.9759615384615384
# There are 105 negatives images and 101 positives images on the Validation dataset: rate= 1.0396039603960396
# There are 125 negatives images and 132 positives images on the Testing dataset: rate= 0.946969696969697
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 331ms/step - loss: 0.4365 - accuracy: 0.8431 - val_loss: 0.2032 - val_accuracy: 0.9320
# Epoch 2/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.2048 - accuracy: 0.9136 - val_loss: 0.3572 - val_accuracy: 0.8641
# Epoch 3/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1927 - accuracy: 0.9234 - val_loss: 0.2387 - val_accuracy: 0.9126
# Epoch 4/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.1536 - accuracy: 0.9428 - val_loss: 0.2138 - val_accuracy: 0.9320
# Epoch 5/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.1318 - accuracy: 0.9513 - val_loss: 0.1679 - val_accuracy: 0.9369
# Epoch 6/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1119 - accuracy: 0.9586 - val_loss: 0.1496 - val_accuracy: 0.9466
# Epoch 7/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1042 - accuracy: 0.9599 - val_loss: 0.1399 - val_accuracy: 0.9515
# Epoch 8/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0963 - accuracy: 0.9659 - val_loss: 0.1340 - val_accuracy: 0.9515
# Epoch 9/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0892 - accuracy: 0.9708 - val_loss: 0.1305 - val_accuracy: 0.9515
# Epoch 10/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0830 - accuracy: 0.9732 - val_loss: 0.1274 - val_accuracy: 0.9612
# Epoch 11/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0772 - accuracy: 0.9757 - val_loss: 0.1246 - val_accuracy: 0.9612
# Epoch 12/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0724 - accuracy: 0.9793 - val_loss: 0.1230 - val_accuracy: 0.9612
# Epoch 13/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0679 - accuracy: 0.9805 - val_loss: 0.1230 - val_accuracy: 0.9612
# Epoch 14/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0637 - accuracy: 0.9830 - val_loss: 0.1252 - val_accuracy: 0.9612
# Epoch 15/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0590 - accuracy: 0.9854 - val_loss: 0.1251 - val_accuracy: 0.9612
# Epoch 16/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0553 - accuracy: 0.9866 - val_loss: 0.1262 - val_accuracy: 0.9612
# Epoch 17/30
# 26/26 [==============================] - 8s 305ms/step - loss: 0.0516 - accuracy: 0.9878 - val_loss: 0.1285 - val_accuracy: 0.9612
# Epoch 18/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0484 - accuracy: 0.9891 - val_loss: 0.1324 - val_accuracy: 0.9612
# Epoch 19/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0452 - accuracy: 0.9903 - val_loss: 0.1346 - val_accuracy: 0.9612
# Epoch 20/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0424 - accuracy: 0.9915 - val_loss: 0.1352 - val_accuracy: 0.9612
# Epoch 21/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0400 - accuracy: 0.9939 - val_loss: 0.1377 - val_accuracy: 0.9612
# Epoch 22/30
# 26/26 [==============================] - 8s 305ms/step - loss: 0.0378 - accuracy: 0.9939 - val_loss: 0.1384 - val_accuracy: 0.9612
# Epoch 23/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0358 - accuracy: 0.9939 - val_loss: 0.1406 - val_accuracy: 0.9563
# Epoch 24/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0339 - accuracy: 0.9951 - val_loss: 0.1419 - val_accuracy: 0.9563
# Epoch 25/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0322 - accuracy: 0.9951 - val_loss: 0.1415 - val_accuracy: 0.9563
# Epoch 26/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0309 - accuracy: 0.9951 - val_loss: 0.1437 - val_accuracy: 0.9563
# Epoch 27/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0302 - accuracy: 0.9951 - val_loss: 0.1479 - val_accuracy: 0.9563
# Epoch 28/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0293 - accuracy: 0.9951 - val_loss: 0.1522 - val_accuracy: 0.9563
# Epoch 29/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0286 - accuracy: 0.9951 - val_loss: 0.1582 - val_accuracy: 0.9563
# Epoch 30/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0282 - accuracy: 0.9964 - val_loss: 0.1688 - val_accuracy: 0.9515
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 221ms/step - loss: 0.0975 - accuracy: 0.9572
#
# Accuracy on the Testing dataset: 95.7198441028595 %
#
# --------------
# ITERATION: 9
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 393 negatives images and 429 positives images on the Training dataset: rate= 0.916083916083916
# There are 88 negatives images and 118 positives images on the Validation dataset: rate= 0.7457627118644068
# There are 133 negatives images and 124 positives images on the Testing dataset: rate= 1.0725806451612903
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 331ms/step - loss: 0.4436 - accuracy: 0.8236 - val_loss: 0.2128 - val_accuracy: 0.9223
# Epoch 2/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1872 - accuracy: 0.9270 - val_loss: 0.1956 - val_accuracy: 0.9320
# Epoch 3/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1581 - accuracy: 0.9319 - val_loss: 0.1882 - val_accuracy: 0.9320
# Epoch 4/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1460 - accuracy: 0.9416 - val_loss: 0.1976 - val_accuracy: 0.9369
# Epoch 5/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1352 - accuracy: 0.9440 - val_loss: 0.1970 - val_accuracy: 0.9320
# Epoch 6/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1241 - accuracy: 0.9489 - val_loss: 0.1907 - val_accuracy: 0.9369
# Epoch 7/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1140 - accuracy: 0.9550 - val_loss: 0.1851 - val_accuracy: 0.9369
# Epoch 8/30
# 26/26 [==============================] - 8s 305ms/step - loss: 0.1055 - accuracy: 0.9599 - val_loss: 0.1807 - val_accuracy: 0.9369
# Epoch 9/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0980 - accuracy: 0.9659 - val_loss: 0.1765 - val_accuracy: 0.9369
# Epoch 10/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0912 - accuracy: 0.9659 - val_loss: 0.1722 - val_accuracy: 0.9369
# Epoch 11/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0848 - accuracy: 0.9708 - val_loss: 0.1691 - val_accuracy: 0.9369
# Epoch 12/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0790 - accuracy: 0.9720 - val_loss: 0.1659 - val_accuracy: 0.9369
# Epoch 13/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0737 - accuracy: 0.9757 - val_loss: 0.1623 - val_accuracy: 0.9369
# Epoch 14/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0686 - accuracy: 0.9769 - val_loss: 0.1595 - val_accuracy: 0.9369
# Epoch 15/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0639 - accuracy: 0.9793 - val_loss: 0.1571 - val_accuracy: 0.9369
# Epoch 16/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0595 - accuracy: 0.9805 - val_loss: 0.1545 - val_accuracy: 0.9369
# Epoch 17/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0554 - accuracy: 0.9805 - val_loss: 0.1522 - val_accuracy: 0.9369
# Epoch 18/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0516 - accuracy: 0.9854 - val_loss: 0.1500 - val_accuracy: 0.9369
# Epoch 19/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0481 - accuracy: 0.9854 - val_loss: 0.1480 - val_accuracy: 0.9369
# Epoch 20/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0449 - accuracy: 0.9878 - val_loss: 0.1464 - val_accuracy: 0.9417
# Epoch 21/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0420 - accuracy: 0.9891 - val_loss: 0.1461 - val_accuracy: 0.9417
# Epoch 22/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0392 - accuracy: 0.9915 - val_loss: 0.1443 - val_accuracy: 0.9417
# Epoch 23/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0368 - accuracy: 0.9927 - val_loss: 0.1451 - val_accuracy: 0.9417
# Epoch 24/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0343 - accuracy: 0.9927 - val_loss: 0.1447 - val_accuracy: 0.9417
# Epoch 25/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0322 - accuracy: 0.9939 - val_loss: 0.1471 - val_accuracy: 0.9417
# Epoch 26/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0301 - accuracy: 0.9939 - val_loss: 0.1475 - val_accuracy: 0.9369
# Epoch 27/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0284 - accuracy: 0.9939 - val_loss: 0.1522 - val_accuracy: 0.9369
# Epoch 28/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0266 - accuracy: 0.9939 - val_loss: 0.1519 - val_accuracy: 0.9320
# Epoch 29/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0252 - accuracy: 0.9939 - val_loss: 0.1590 - val_accuracy: 0.9272
# Epoch 30/30
# 26/26 [==============================] - 8s 305ms/step - loss: 0.0238 - accuracy: 0.9951 - val_loss: 0.1599 - val_accuracy: 0.9272
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 217ms/step - loss: 0.0979 - accuracy: 0.9689
#
# Accuracy on the Testing dataset: 96.88715934753418 %
#
# --------------
# ITERATION: 10
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 393 negatives images and 429 positives images on the Training dataset: rate= 0.916083916083916
# There are 95 negatives images and 111 positives images on the Validation dataset: rate= 0.8558558558558559
# There are 124 negatives images and 133 positives images on the Testing dataset: rate= 0.9323308270676691
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 320ms/step - loss: 0.7480 - accuracy: 0.7409 - val_loss: 0.2375 - val_accuracy: 0.9126
# Epoch 2/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1726 - accuracy: 0.9319 - val_loss: 0.2131 - val_accuracy: 0.9126
# Epoch 3/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1634 - accuracy: 0.9294 - val_loss: 0.1971 - val_accuracy: 0.9175
# Epoch 4/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1530 - accuracy: 0.9367 - val_loss: 0.1854 - val_accuracy: 0.9272
# Epoch 5/30
# 26/26 [==============================] - 8s 305ms/step - loss: 0.1480 - accuracy: 0.9367 - val_loss: 0.1765 - val_accuracy: 0.9272
# Epoch 6/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0
30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0583 - accuracy: 0.9818 - val_loss: 0.1023 - val_accuracy: 0.9660
# Epoch 29/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0568 - accuracy: 0.9830 - val_loss: 0.1005 - val_accuracy: 0.9660
# Epoch 30/30
# 26/26 [==============================] - 8s 306ms/step - loss: 0.0545 - accuracy: 0.9854 - val_loss: 0.0993 - val_accuracy: 0.9660
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 216ms/step - loss: 0.1172 - accuracy: 0.9572
#
# Accuracy on the Testing dataset: 95.7198441028595 %
#
# --------------
# ITERATION: 11
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 390 negatives images and 432 positives images on the Training dataset: rate= 0.9027777777777778
# There are 112 negatives images and 94 positives images on the Validation dataset: rate= 1.1914893617021276
# There are 126 negatives images and 131 positives images on the Testing dataset: rate= 0.9618320610687023
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 25088)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# ...
# Epoch 12/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1245 - accuracy: 0.9550 - val_loss: 0.1229 - val_accuracy: 0.9563
# Epoch 13/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1190 - accuracy: 0.9538 - val_loss: 0.1193 - val_accuracy: 0.9612
# Epoch 14/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1147 - accuracy: 0.9538 - val_loss: 0.1168 - val_accuracy: 0.9660
# Epoch 15/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.1090 - accuracy: 0.9586 - val_loss: 0.1141 - val_accuracy: 0.9660
# Epoch 16/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.1028 - accuracy: 0.9623 - val_loss: 0.1113 - val_accuracy: 0.9660
# Epoch 17/30
# 26/26 [==============================] - 8s 312ms/step - loss: 0.0982 - accuracy: 0.9635 - val_loss: 0.1106 - val_accuracy: 0.9660
# Epoch 18/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0953 - accuracy: 0.9659 - val_loss: 0.1085 - val_accuracy: 0.9660
# Epoch 19/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0896 - accuracy: 0.9708 - val_loss: 0.1063 - val_accuracy: 0.9709
# Epoch 20/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0866 - accuracy: 0.9696 - val_loss: 0.1044 - val_accuracy: 0.9709
# Epoch 21/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0843 - accuracy: 0.9708 - val_loss: 0.1036 - val_accuracy: 0.9709
# Epoch 22/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0815 - accuracy: 0.9708 - val_loss: 0.1038 - val_accuracy: 0.9709
# Epoch 23/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0788 - accuracy: 0.9708 - val_loss: 0.1026 - val_accuracy: 0.9709
# Epoch 24/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0735 - accuracy: 0.9757 - val_loss: 0.1029 - val_accuracy: 0.9709
# Epoch 25/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0703 - accuracy: 0.9769 - val_loss: 0.0995 - val_accuracy: 0.9757
# Epoch 26/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0673 - accuracy: 0.9781 - val_loss: 0.0998 - val_accuracy: 0.9757
# Epoch 27/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0644 - accuracy: 0.9805 - val_loss: 0.0983 - val_accuracy: 0.9757
# Epoch 28/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0615 - accuracy: 0.9805 - val_loss: 0.0974 - val_accuracy: 0.9757
# Epoch 29/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 0.0968 - val_accuracy: 0.9757
# Epoch 30/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0533 - accuracy: 0.9842 - val_loss: 0.0957 - val_accuracy: 0.9757
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 223ms/step - loss: 0.0681 - accuracy: 0.9805
#
# Accuracy on the Testing dataset: 98.05447459220886 %
#
# --------------
# ITERATION: 49
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 395 negatives images and 427 positives images on the Training dataset: rate= 0.9250585480093677
# There are 102 negatives images and 104 positives images on the Validation dataset: rate= 0.9807692307692307
# There are 126 negatives images and 131 positives images on the Testing dataset: rate= 0.9618320610687023
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_48 (Flatten)         (None, 25088)             0
# _________________________________________________________________
# dense_96 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_97 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 10s 344ms/step - loss: 0.3755 - accuracy: 0.8443 - val_loss: 0.2918 - val_accuracy: 0.8981
# Epoch 2/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.2719 - accuracy: 0.8990 - val_loss: 0.2257 - val_accuracy: 0.9078
# Epoch 3/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.2350 - accuracy: 0.9161 - val_loss: 0.2310 - val_accuracy: 0.8932
# Epoch 4/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1680 - accuracy: 0.9246 - val_loss: 0.2070 - val_accuracy: 0.8981
# Epoch 5/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.1526 - accuracy: 0.9331 - val_loss: 0.1991 - val_accuracy: 0.9029
# Epoch 6/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1522 - accuracy: 0.9331 - val_loss: 0.1955 - val_accuracy: 0.8932
# Epoch 7/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1432 - accuracy: 0.9355 - val_loss: 0.1925 - val_accuracy: 0.8932
# Epoch 8/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1320 - accuracy: 0.9404 - val_loss: 0.1913 - val_accuracy: 0.8932
# Epoch 9/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1207 - accuracy: 0.9477 - val_loss: 0.1883 - val_accuracy: 0.8981
# Epoch 10/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1129 - accuracy: 0.9513 - val_loss: 0.1881 - val_accuracy: 0.9126
# Epoch 11/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1067 - accuracy: 0.9550 - val_loss: 0.1865 - val_accuracy: 0.9175
# Epoch 12/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.1012 - accuracy: 0.9611 - val_loss: 0.1844 - val_accuracy: 0.9272
# Epoch 13/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0962 - accuracy: 0.9611 - val_loss: 0.1829 - val_accuracy: 0.9320
# Epoch 14/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0902 - accuracy: 0.9672 - val_loss: 0.1809 - val_accuracy: 0.9272
# Epoch 15/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0859 - accuracy: 0.9708 - val_loss: 0.1802 - val_accuracy: 0.9272
# Epoch 16/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0807 - accuracy: 0.9769 - val_loss: 0.1803 - val_accuracy: 0.9223
# Epoch 17/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0762 - accuracy: 0.9781 - val_loss: 0.1816 - val_accuracy: 0.9223
# Epoch 18/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0719 - accuracy: 0.9818 - val_loss: 0.1807 - val_accuracy: 0.9223
# Epoch 19/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0676 - accuracy: 0.9842 - val_loss: 0.1796 - val_accuracy: 0.9223
# Epoch 20/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0638 - accuracy: 0.9854 - val_loss: 0.1805 - val_accuracy: 0.9223
# Epoch 21/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0601 - accuracy: 0.9891 - val_loss: 0.1787 - val_accuracy: 0.9223
# Epoch 22/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0565 - accuracy: 0.9903 - val_loss: 0.1795 - val_accuracy: 0.9223
# Epoch 23/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0536 - accuracy: 0.9903 - val_loss: 0.1785 - val_accuracy: 0.9223
# Epoch 24/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0510 - accuracy: 0.9915 - val_loss: 0.1794 - val_accuracy: 0.9223
# Epoch 25/30
# 26/26 [==============================] - 8s 312ms/step - loss: 0.0482 - accuracy: 0.9927 - val_loss: 0.1788 - val_accuracy: 0.9223
# Epoch 26/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0456 - accuracy: 0.9927 - val_loss: 0.1799 - val_accuracy: 0.9223
# Epoch 27/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0433 - accuracy: 0.9951 - val_loss: 0.1788 - val_accuracy: 0.9223
# Epoch 28/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0408 - accuracy: 0.9964 - val_loss: 0.1799 - val_accuracy: 0.9223
# Epoch 29/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0386 - accuracy: 0.9964 - val_loss: 0.1794 - val_accuracy: 0.9223
# Epoch 30/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0367 - accuracy: 0.9964 - val_loss: 0.1794 - val_accuracy: 0.9223
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 217ms/step - loss: 0.1241 - accuracy: 0.9572
#
# Accuracy on the Testing dataset: 95.7198441028595 %
#
# --------------
# ITERATION: 50
# --------------
#
# ---------------------------------------------------------------------------
# There are 822 images for the Training with their respectives 822 labels.
# There are 206 images for the Validation with their respectives 206 labels.
# There are 257 images for the Testing with their respectives 257 labels.
# ---------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------------------------------------
# There are 408 negatives images and 414 positives images on the Training dataset: rate= 0.9855072463768116
# There are 109 negatives images and 97 positives images on the Validation dataset: rate= 1.1237113402061856
# There are 119 negatives images and 138 positives images on the Testing dataset: rate= 0.8623188405797102
# -----------------------------------------------------------------------------------------------------------
#
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_49 (Flatten)         (None, 25088)             0
# _________________________________________________________________
# dense_98 (Dense)             (None, 256)               6422784
# _________________________________________________________________
# dense_99 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
#
# ------------------------------------
# Training the Tranfer Learning Model
# ------------------------------------
#
# Epoch 1/30
# 26/26 [==============================] - 9s 323ms/step - loss: 0.4764 - accuracy: 0.8309 - val_loss: 0.2032 - val_accuracy: 0.9078
# Epoch 2/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1714 - accuracy: 0.9307 - val_loss: 0.1835 - val_accuracy: 0.9078
# Epoch 3/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1630 - accuracy: 0.9319 - val_loss: 0.1774 - val_accuracy: 0.9175
# Epoch 4/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1482 - accuracy: 0.9416 - val_loss: 0.1737 - val_accuracy: 0.9320
# Epoch 5/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1358 - accuracy: 0.9477 - val_loss: 0.1655 - val_accuracy: 0.9369
# Epoch 6/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.1282 - accuracy: 0.9513 - val_loss: 0.1578 - val_accuracy: 0.9417
# Epoch 7/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1203 - accuracy: 0.9550 - val_loss: 0.1511 - val_accuracy: 0.9417
# Epoch 8/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.1134 - accuracy: 0.9586 - val_loss: 0.1443 - val_accuracy: 0.9417
# Epoch 9/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.1064 - accuracy: 0.9635 - val_loss: 0.1394 - val_accuracy: 0.9466
# Epoch 10/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0999 - accuracy: 0.9647 - val_loss: 0.1342 - val_accuracy: 0.9466
# Epoch 11/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0937 - accuracy: 0.9672 - val_loss: 0.1294 - val_accuracy: 0.9466
# Epoch 12/30
# 26/26 [==============================] - 8s 307ms/step - loss: 0.0877 - accuracy: 0.9720 - val_loss: 0.1251 - val_accuracy: 0.9515
# Epoch 13/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0827 - accuracy: 0.9769 - val_loss: 0.1220 - val_accuracy: 0.9515
# Epoch 14/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0772 - accuracy: 0.9769 - val_loss: 0.1182 - val_accuracy: 0.9563
# Epoch 15/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0720 - accuracy: 0.9781 - val_loss: 0.1155 - val_accuracy: 0.9563
# Epoch 16/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0675 - accuracy: 0.9805 - val_loss: 0.1123 - val_accuracy: 0.9563
# Epoch 17/30
# 26/26 [==============================] - 8s 313ms/step - loss: 0.0635 - accuracy: 0.9830 - val_loss: 0.1101 - val_accuracy: 0.9563
# Epoch 18/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0589 - accuracy: 0.9854 - val_loss: 0.1073 - val_accuracy: 0.9563
# Epoch 19/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0552 - accuracy: 0.9854 - val_loss: 0.1054 - val_accuracy: 0.9612
# Epoch 20/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0513 - accuracy: 0.9866 - val_loss: 0.1029 - val_accuracy: 0.9612
# Epoch 21/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0481 - accuracy: 0.9878 - val_loss: 0.1010 - val_accuracy: 0.9612
# Epoch 22/30
# 26/26 [==============================] - 8s 308ms/step - loss: 0.0446 - accuracy: 0.9878 - val_loss: 0.0984 - val_accuracy: 0.9612
# Epoch 23/30
# 26/26 [==============================] - 8s 313ms/step - loss: 0.0415 - accuracy: 0.9891 - val_loss: 0.0970 - val_accuracy: 0.9612
# Epoch 24/30
# 26/26 [==============================] - 8s 310ms/step - loss: 0.0385 - accuracy: 0.9915 - val_loss: 0.0948 - val_accuracy: 0.9612
# Epoch 25/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0357 - accuracy: 0.9927 - val_loss: 0.0930 - val_accuracy: 0.9612
# Epoch 26/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0330 - accuracy: 0.9939 - val_loss: 0.0922 - val_accuracy: 0.9612
# Epoch 27/30
# 26/26 [==============================] - 8s 311ms/step - loss: 0.0307 - accuracy: 0.9951 - val_loss: 0.0910 - val_accuracy: 0.9612
# Epoch 28/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0282 - accuracy: 0.9951 - val_loss: 0.0898 - val_accuracy: 0.9612
# Epoch 29/30
# 26/26 [==============================] - 8s 313ms/step - loss: 0.0263 - accuracy: 0.9951 - val_loss: 0.0885 - val_accuracy: 0.9612
# Epoch 30/30
# 26/26 [==============================] - 8s 309ms/step - loss: 0.0241 - accuracy: 0.9964 - val_loss: 0.0867 - val_accuracy: 0.9612
#
# ------------------------
# Evaluation of the Model
# ------------------------
# 9/9 [==============================] - 2s 222ms/step - loss: 0.0863 - accuracy: 0.9728
#
# Accuracy on the Testing dataset: 97.27626442909241 %

# %% [markdown]
# #Saving the calculated metrics in a .csv file

# %%
import pandas as pd

path_csv = '/content/drive/MyDrive/Agglutination/'
name_metrics_csv = 'stats_metrics.csv'

dict_metrics = dict({'Accuracy':accuracies, 'Precision':precisions, 'Sensitivity':sensitivities, 'Specificity':specificities, 'F1 Score':F1_scores, 'AUC': auc_values})
df_metrics = pd.DataFrame(dict_metrics)
df_metrics.to_csv(path_csv + name_metrics_csv, index=False)
df_metrics
# Out:
#     Accuracy  Precision  Sensitivity  Specificity  F1 Score       AUC
# 0   0.957198   0.938356     0.985612     0.923729  0.961404  0.993781
# 1   0.957198   0.968000     0.945312     0.968992  0.956522  0.994186
# 2   0.957198   0.954198     0.961538     0.952756  0.957854  0.994367
# 3   0.953307   0.991525     0.914062     0.992248  0.951220  0.996972
# 4   0.957198   0.984496     0.933824     0.983471  0.958491  0.996719
# 5   0.941634   0.913386     0.966667     0.919708  0.939271  0.991119
# 6   0.980545   1.000000     0.962687     1.000000  0.980989  0.997998
# 7   0.957198   0.984000     0.931818     0.984000  0.957198  0.997576
# 8   0.968872   1.000000     0.935484     1.000000  0.966667  0.995331
# 9   0.957198   0.976562     0.939850     0.975806  0.957854  0.991632
# 10  0.941634   0.991525     0.893130     0.992063  0.939759  0.997334
# 11  0.976654   0.984733     0.969925     0.983871  0.977273  0.996483
# 12  0.968872   1.000000     0.936508     1.000000  0.967213  0.993760
# 13  0.964981   1.000000     0.936170     1.000000  0.967033  0.993580
